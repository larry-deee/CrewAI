# %% [markdown]
# <a href="https://colab.research.google.com/github/larry-deee/CrewAI/blob/main/Ethical_AI_Agents_Prototype_sample_v2_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🤖 Building an AI Dream Team: Bias Detection System with CrewAI
#
# Hey tech fam! 👋 Ready to revolutionize how we handle bias in documents? I'm super excited to share this amazing prototype project that brings together multiple AI agents to create something pretty cool ✨
#
# ## 🌟 What's This All About?
#
# Picture this: Five AI agents working together like a well-oiled machine 🔧, each bringing their unique superpowers to:
# - 📚 Read your documents with precision
# - 🎯 Extract bias patterns from academic research
# - 🔍 Spot potentially biased language
# - ✍️ Rewrite content to be more inclusive
# - ✅ Double-check everything
#
# ## 🚀 Features That'll Blow Your Mind
#
# - 🤝 Multi-agent collaboration powered by CrewAI
# - 📄 Smart PDF processing capabilities
# - 📊 Super detailed metrics for data nerds
# - 📈 Tableau-ready metrics (because who doesn't love beautiful dashboards?)
#
#
# ## 🦸‍♂️ Meet the AI Dream Team
#
# 1. **DocumentReader** - The Speedreader 📚
# 2. **LexiconExtractor** - The Knowledge Guru 🎓
# 3. **DocumentComparer** - The Detail Detective 🔍
# 4. **TextRewriter** - The Wordsmith ✍️
# 5. **TextValidator** - The Quality Guardian ⭐
#
# ## 📊 Data & Metrics (For The Numbers People!)
#
# Get ready for some seriously cool metrics:
# - ⏱️ Execution timing
# - 📈 Performance stats
# - 💰 Cost tracking
# - ✅ Validation results
#
# ## ✅ I'm no coder - All code was built with the help of AI

# %% [markdown]
# ![2025-01-23_23-45-20.png](data:image/png;base64,...)

# %%
##Install CrewAI and dependancies and download reference docs
# !pip install crewai crewai[tools] --upgrade
# !pip install PyPDF2 openai gdown
# !wget -c "https://www.unescwa.org/sites/default/files/services/doc/guidelines_gender-sensitive_language_e-a.pdf"
# !wget -c 'https://arxiv.org/pdf/2201.08675' -O '2201_08675.pdf'
# !wget -c "https://dam-prod2.media.mit.edu/x/2018/02/06/Gender%20Shades%20Intersectional%20Accuracy%20Disparities.pdf" -O "gender_shades.pdf"

# %%
## Sample Text

document_text = """
**Job Title:  Dynamic Sales Leader - Join Our Winning Team!**

**Company: Apex Innovations Inc.**

**Location:  Our Lively Downtown Headquarters**

**About Apex Innovations:**

At Apex Innovations, we're a family. We're a team of high-achievers who are passionate about pushing boundaries and celebrating success.
We value loyalty, hard work, and a can-do attitude. We believe in maintaining a close-knit environment where everyone feels
comfortable and shares similar values. Our ideal candidate will seamlessly integrate into our existing team dynamic – we're a predominantly
male group, if that matters to you.

**Responsibilities:**

* Drive sales growth through proactive outreach and relationship building.
* Develop and execute sales strategies to achieve ambitious targets.
* Manage and mentor a team of junior sales representatives, guiding them towards success.
* Prepare and deliver compelling presentations to potential clients.
* Network within the industry to identify new opportunities.
* Ensure all sales activities align with company standards and ethical guidelines (as we see them).

**Qualifications:**

* Proven track record of exceeding sales targets (minimum 5 years experience preferred, but frankly, someone with the energy of a recent college grad is ideal).
* Exceptional communication and interpersonal skills (someone who can charm any client, especially the ladies).
* Strong leadership qualities (someone who can command respect without being *too* emotional).
* Excellent presentation skills and comfortable speaking to large groups.
* Proficiency in CRM software and Microsoft Office Suite.
* Must be able to handle the pressures of a demanding sales environment.
* A college degree is preferred, but frankly, street smarts and a good head on your shoulders are what really matter.
* We're looking for a real "go-getter" – someone who isn't afraid to hustle, even if it means late nights.
* Must possess a valid driver's license and reliable transportation.

**Bonus Points (Not Required, But a Plus):**

* Experience selling within the **construction equipment industry**.
* Involvement in **Sigma Alpha Epsilon fraternity** or a similar organization.
* Strong network of contacts within our existing client base at **the local country club**.
* If you're the spouse or relative of **John Smith in our Finance department**, please mention it in your application!

**Benefits:**

* Competitive salary and commission structure.
* Comprehensive health and dental insurance (for the right cultural fit).
* Paid time off and holidays.
* Opportunities for professional development and advancement (for those who show real dedication to the team).
* Regular team-building events and social gatherings, like our **annual golf outing**.

**To Apply:**

Please submit your resume and cover letter to [email protected] We look forward to hearing from sharp, ambitious individuals ready to make a significant impact! Please include a recent photo so we can put a face to the name.

**EEO Statement (Appears, But May Be Undermined by Other Language):**

Apex Innovations Inc. is an equal opportunity employer and values diversity at our company. We do not discriminate on the basis of race, religion, color, national origin, gender, sexual orientation, age, marital status, veteran status, or disability status. However, cultural fit is really important to us, and our team is very close-knit.
"""
file_path = "sample.txt"

try:
    with open(file_path, 'w', encoding='utf-8') as f:
        f.write(document_text)
    print(f"The job posting has been written to '{file_path}'.")
except Exception as e:
    print(f"An error occurred while writing to the file: {e}")
# Out:
# The job posting has been written to 'sample.txt'.

# %%
## Sample Text v2.0

document_text = """
## Dynamic Sales Executive Position at TechFront Solutions

### About Us
We're a young, high-energy startup disrupting the tech space. Our team of recent graduates works hard and plays harder, fostering a vibrant culture where everyone is like family.

### The Role
Seeking an attractive, energetic female sales executive to be the face of our company. The ideal candidate will join our picture-perfect team of dynamic professionals in our fast-paced environment.

### Key Requirements
- Must have graduated within the last 5 years from a top-tier university
- Native English speaker with mother tongue fluency required
- Young, fresh mindset with ability to adapt to our startup culture
- Must be able to lift 50lbs regularly for occasional office events
- Handsome presentation and professional appearance mandatory
- Strong cultural fit - no 9-to-5 mindset
- Must be able to work late nights and weekends regularly
- Clean-cut appearance and excellent grooming standards essential

### What We Offer
- Young, vibrant office atmosphere
- Regular team happy hours and weekend retreats
- Standing desks and on-site gym (physical fitness essential)
- Competitive salary for a recent graduate
- Fast-track growth for those willing to prioritize work over personal commitments
- Modern office in a trendy neighborhood (no remote work - we believe in face-time)

### Physical Requirements
- Must be able to maintain high energy levels throughout extended workdays
- Excellent physical stamina for client entertainment
- No accommodations available for physical limitations
- Must be able to wear company-branded attire (sized XS-L available)

### Culture Fit
- High-energy personality essential
- Must fit in with our work-hard-play-hard mentality
- Looking for someone who can be "one of the guys"
- No clock-watchers or those with family obligations

Qualified candidates should submit CV with recent photograph and age verification to recruiting@techfront.example.com

TechFront Solutions is an equal opportunity employer.*

*While we welcome all applications, candidates fitting our vibrant culture will be prioritized.
"""
file_path = "sample.txt"

try:
    with open(file_path, 'w', encoding='utf-8') as f:
        f.write(document_text)
    print(f"The job posting has been written to '{file_path}'.")
except Exception as e:
    print(f"An error occurred while writing to the file: {e}")

# %%
## Sample Text v3.0

document_text = """
## Senior Client Relations Director
### EliteCore Ventures - Global Luxury Division

### About Our Legacy
At EliteCore Ventures, we maintain a century-old tradition of excellence in the luxury consulting space. Our heritage shapes every aspect of our operation, from our carefully curated team to our prestigious client portfolio. We've built our reputation through maintaining exceptional standards that reflect our commitment to traditional values and refined corporate culture.

### Position Overview
We seek an exceptional female executive to represent our prestigious brand in client-facing situations. This role demands a unique combination of natural sophistication, cultural refinement, and unwavering commitment to excellence. The ideal candidate will seamlessly integrate into our established corporate ecosystem while maintaining the highest standards of personal and professional presentation.

### Essential Qualifications
**Educational Background**
- Traditional four-year degree from an accredited private institution (online degrees not considered)
- Recent graduation (within 5 years) from top-tier university
- Proven academic excellence with traditional liberal arts foundation
- Study abroad experience in Western European institutions preferred
- Command of proper English essential; regional accents may impact client communication

**Professional Experience**
- Pure corporate background in luxury sector
- Demonstrated experience in high-society settings
- Background in traditional business environments (non-military)
- Legacy company experience preferred over startup exposure

**Cultural Competencies**
- Natural ability to navigate exclusive social settings
- Refined palate for fine dining and wine appreciation
- Active membership in prestigious social organizations
- Demonstrated understanding of luxury brand hierarchies
- Experience with yacht club and country club protocols
- Proven ability to maintain appropriate social media presence (minimum 10K followers)
- Alignment with traditional American values

### Position Requirements
**Professional Presentation**
- Impeccable grooming standards aligned with luxury sector expectations
- Natural, polished appearance (company standards apply)
- Height-weight proportionate for sample-size wardrobe events
- Clean-cut, classic appearance (no visible modifications)
- Designer wardrobe appropriate for elite client interaction

**Physical Requirements**
- Full mobility required for client entertainment
- Stamina for extended social engagements
- Ability to maintain peak wellness standards
- Medical history compatible with intensive schedule
- Genetic predisposition to wellness preferred

**Lifestyle Alignment**
- Residence in approved metropolitan neighborhoods
- Ownership of luxury vehicle (current model year)
- Active participation in traditional social seasons
- Availability for evening/weekend client entertainment
- Comfortable with formal dining protocols
- Ability to host at approved social venues
- Participation in team wellness initiatives

### Company Benefits
- Exclusive health club membership
- Annual designer wardrobe allowance
- Luxury vehicle allowance
- Private social club memberships
- Traditional holiday schedule
- Company events at premium venues
- Access to elite client network

### Work Environment
- Heritage office in premier location
- Traditional in-person workplace culture
- Regular team social engagements
- Fast-paced, high-energy atmosphere
- Regular travel to approved destinations
- Formal business environment
- Premium client entertainment venues

### Additional Considerations
- Must maintain residence in approved neighborhoods
- Background verification includes social circle review
- Health screening includes family medical history
- Social media presence subject to ongoing review
- Personal life choices must align with company image
- Lifestyle modifications may be required
- Regular appearance and wellness evaluations

### Application Requirements
Please submit comprehensive portfolio including:
- Family background summary
- Social club affiliations
- Residential history
- Full medical disclosure
- Genetic screening consent
- Social media analytics
- Personal style portfolio
- Character references from approved institutions

EliteCore Ventures maintains an equal opportunity hiring policy within our established parameters of excellence.*

*Final candidates must meet all unstated quality metrics as determined by our executive committee.

### Notes
- Position requires adherence to unwritten social protocols
- Candidates must demonstrate natural cultural refinement
- Traditional values alignment essential
- Lifestyle flexibility required
- Company culture reflects established social hierarchies
- Merit-based advancement within traditional frameworks
- Comprehensive background alignment required
"""
file_path = "sample.txt"

try:
    with open(file_path, 'w', encoding='utf-8') as f:
        f.write(document_text)
    print(f"The job posting has been written to '{file_path}'.")
except Exception as e:
    print(f"An error occurred while writing to the file: {e}")

# %% [markdown]
# Example with no Logging

# %%
# CrewAI Imports
from crewai import Agent, Task, Crew, LLM, Process
from crewai_tools import PDFSearchTool, FileReadTool
from google.colab import userdata
import os
import json
import re

# Set up environment variables
os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')
os.environ["ANTHROPIC_API_KEY"] = userdata.get('ANTHROPIC_API_KEY')
os.environ["HF_TOKEN"] = userdata.get('HF_TOKEN')

# Initialize LLM and tools
#llm = LLM(model="anthropic/claude-3-5-haiku-latest", temperature=0.55)
llm = LLM(model="anthropic/claude-3-5-sonnet-latest", temperature=0.55, max_tokens=4000)
#llm = LLM(model="openai/gpt-4o-2024-11-20", temperature=0.55)

file_read_tool = FileReadTool(file_path="/content/sample.txt")

# Ingest PDFs
pdf_paths = [
    "/content/2201_08675.pdf",
    "/content/guidelines_gender-sensitive_language_e-a.pdf",
    "/content/gender_shades.pdf"
]

pdf_tools = []
for path in pdf_paths:
    try:
        pdf_tool = PDFSearchTool(pdf=path)
        pdf_tools.append(pdf_tool)
        print(f"Successfully ingested PDF: {path}")
    except Exception as e:
        print(f"Error ingesting PDF {path}: {e}")

# Define Agents
document_reader = Agent(
    name="DocumentReader",
    role="Document Reading Agent",
    goal="Read and process input text files accurately",
    backstory="An AI expert in processing and extracting text from files",
    tools=[file_read_tool],
    llm=llm
)

lexicon_extractor = Agent(
    name="LexiconExtractor",
    role="Lexicon Extraction Agent",
    goal="Extract structured lexicons for gender bias and stereotypes from PDFs.",
    backstory="An AI expert skilled in processing and structuring large volumes of text data.",
    tools=pdf_tools + [file_read_tool],
    llm=llm
)

document_comparer = Agent(
    name="DocumentComparer",
    role="Document Comparison Agent",
    goal="Identify and flag problematic terms based on lexicons.",
    backstory="A meticulous copy editor with expertise in identifying bias.",
    llm=llm
)

text_rewriter = Agent(
    name="TextRewriter",
    role="Rewriting Agent",
    goal="Rewrite flagged terms with inclusive alternatives while maintaining context.",
    backstory="A skilled writer ensuring clear, inclusive communication.",
    llm=llm
)

text_validator = Agent(
    name="TextValidator",
    role="Validation Agent",
    goal="Review rewritten text for approval.",
    backstory="An expert ensuring compliance and accuracy in written materials.",
    tools=[file_read_tool],
    llm=llm
)

# Define Tasks
read_task = Task(
    description=f"Read the input text file from {file_read_tool}. Confirm you have read the file.",
    expected_output="Raw text content from the file",
    verbose=True,
    agent=document_reader
)

extract_task = Task(
    description="Extract lexicons for gender bias and stereotypes from the PDFs.",
    expected_output="JSON formatted lexicons.",
    output_file="lexicons.json",
    agent=lexicon_extractor,
    context=[read_task]
)

compare_task = Task(
    description="Compare the input document text against the lexicons.",
    expected_output="Flagged terms with suggestions for inclusive language.",
    output_file="flagged_terms.json",
    verbose=True,
    agent=document_comparer,
    context=[read_task, extract_task]
)

rewrite_task = Task(
    name='rewrite_task',
    description="Rewrite the original input document text into a compliant version.",
    expected_output="""
        A complete rewritten version of the original text with all applicable modifications
        applied from the lexicon. Ensure your output is a variation of the original text
    """,
    output_file="sample_fixed.txt",
    agent=text_rewriter,
    context=[read_task, compare_task]
)

validate_task = Task(
    description="Validate the original vs. the newly rewritten document.",
    expected_output="Ensure the rewritten text is in compliance.",
    tools=[file_read_tool],
    agent=text_validator,
    context=[read_task, rewrite_task]
)

# Define and Execute Crew
bias_detection_crew = Crew(
    agents=[
        document_reader,
        lexicon_extractor,
        document_comparer,
        text_rewriter,
        text_validator
    ],
    tasks=[
        read_task,
        extract_task,
        compare_task,
        rewrite_task,
        validate_task
    ],
    memory=True,
    process=Process.sequential,
    #max_rpm=5,
    verbose=True
)

# Execute the crew
results = bias_detection_crew.kickoff()
print("Final Output:", results)

# %% [markdown]
# Example with Logging

# %%
# CrewAI Imports
from crewai import Agent, Task, Crew, LLM, Process
from crewai_tools import PDFSearchTool, FileReadTool
from google.colab import userdata
from datetime import datetime
from pathlib import Path
import os
import json
import logging

# Initialize directories and logging
log_dir = Path('/content/logs')
log_dir.mkdir(exist_ok=True)

logger = logging.getLogger('bias_detection_logger')
logger.setLevel(logging.DEBUG)

formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
handlers = [
    logging.FileHandler(log_dir / f'bias_detection_audit_{datetime.now().strftime("%Y%m%d_%H%M%S")}.log'),
    logging.StreamHandler()
]
for handler in handlers:
    handler.setFormatter(formatter)
    logger.addHandler(handler)

# Environment setup
for key in ['OPENAI_API_KEY', 'ANTHROPIC_API_KEY', 'HF_TOKEN']:
    os.environ[key] = userdata.get(key)

# Initialize LLM and tools
llm = LLM(model="openai/gpt-4o-2024-11-20", temperature=0.55)
file_read_tool = FileReadTool(file_path="/content/sample.txt")

# Ingest PDFs
pdf_paths = [
    "/content/2201_08675.pdf",
    "/content/guidelines_gender-sensitive_language_e-a.pdf",
    "/content/gender_shades.pdf"
]
pdf_tools = [PDFSearchTool(pdf=path) for path in pdf_paths]

def step_callback(step_output):
    logger.info(f"Step Output: {str(step_output)}")

def usage_metrics_to_dict(metrics):
    return {
        attr: getattr(metrics, attr, 0)
        for attr in ['prompt_tokens', 'completion_tokens', 'total_tokens', 'cost']
    } if metrics else {}

class CrewMetricsEncoder(json.JSONEncoder):
    def default(self, obj):
        if hasattr(obj, '__dict__'):
            return {k: v for k, v in obj.__dict__.items()
                   if not k.startswith('_') and not callable(v)}
        return str(obj)

def create_tableau_metrics(crew, start_time):
    return {
        "execution_metrics": {
            "timestamp": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
            "run_id": start_time.strftime("%Y%m%d_%H%M%S"),
            "duration": (datetime.now() - start_time).total_seconds(),
            "process_type": str(crew.process),
            "agents_count": len(crew.agents),
            "tasks_count": len(crew.tasks),
            "usage_metrics": usage_metrics_to_dict(crew.usage_metrics),
            "tasks": [{
                "name": task.description[:50] + "...",
                "agent": task.agent.role,
                "status": "completed" if hasattr(task, 'output') else "pending",
                "output_file": getattr(task, 'output_file', None)
            } for task in crew.tasks]
        },
        "agent_metrics": [{
            "role": agent.role,
            "goal": agent.goal,
            "tools_count": len(agent.tools or []),
            "tools": [getattr(tool, 'name', str(tool)) for tool in (agent.tools or [])]
        } for agent in crew.agents],
        "validation_status": "passed" if hasattr(crew.tasks[-1], 'output') and
            "compliant" in str(crew.tasks[-1].output.raw).lower() else "needs_review"
    }

# Define Agents
agents = {
    "document_reader": Agent(
        name="DocumentReader",
        role="Document Reading Agent",
        goal="Read and process input text files accurately",
        backstory="An AI expert in processing and extracting text from files",
        tools=[file_read_tool],
        llm=llm
    ),
    "lexicon_extractor": Agent(
        name="LexiconExtractor",
        role="Lexicon Extraction Agent",
        goal="Extract structured lexicons for gender bias and stereotypes from PDFs.",
        backstory="An AI expert skilled in processing and structuring large volumes of text data.",
        tools=pdf_tools + [file_read_tool],
        llm=llm
    ),
    "document_comparer": Agent(
        name="DocumentComparer",
        role="Document Comparison Agent",
        goal="Identify and flag problematic terms based on lexicons.",
        backstory="A meticulous copy editor with expertise in identifying bias.",
        llm=llm
    ),
    "text_rewriter": Agent(
        name="TextRewriter",
        role="Rewriting Agent",
        goal="Rewrite flagged terms with inclusive alternatives while maintaining context.",
        backstory="A skilled writer ensuring clear, inclusive communication.",
        llm=llm
    ),
    "text_validator": Agent(
        name="TextValidator",
        role="Validation Agent",
        goal="Review rewritten text for approval.",
        backstory="An expert ensuring compliance and accuracy in written materials.",
        tools=[file_read_tool],
        llm=llm
    )
}

# Define Tasks
# Store tasks in a list as we create them for referencing
tasks = []

# First task (no context needed)
tasks.append(Task(
    description=f"Read the input text file from {file_read_tool}. Confirm you have read the file.",
    expected_output="Raw text content from the file",
    verbose=True,
    output_file="logs/read_task_output.txt",
    agent=agents["document_reader"]
))

# Add subsequent tasks with proper context references
tasks.append(Task(
    description=f"Extract highly detailed, audit compliant lexicons for gender bias and stereotypes from the reference documents.",
    expected_output=f"JSON formatted lexicon derived from {pdf_tools}.",
    output_file="logs/lexicons.json",
    verbose=True,
    agent=agents["lexicon_extractor"],
    context=[tasks[0]]
))

tasks.append(Task(
    description="Compare the input document text against the lexicon data.",
    expected_output="Flagged terms with suggestions for inclusive language based on information from lexicon data.",
    output_file="logs/flagged_terms.json",
    verbose=True,
    agent=agents["document_comparer"],
    context=[tasks[0], tasks[1]]
))

tasks.append(Task(
    description="Rewrite the original input document text into a compliant version.",
    expected_output="A complete rewritten version of the original text with all applicable modifications applied from the lexicon.",
    output_file="logs/sample_fixed.txt",
    verbose=True,
    agent=agents["text_rewriter"],
    context=[tasks[0], tasks[2]]
))

tasks.append(Task(
    description="Validate the original vs. the newly rewritten document.",
    expected_output="Ensure the rewritten text is in compliance.",
    verbose=True,
    agent=agents["text_validator"],
    context=[tasks[0], tasks[3]]
))

# Execute Crew
bias_detection_crew = Crew(
    agents=list(agents.values()),
    tasks=tasks,
    memory=True,
    process=Process.sequential,
    verbose=True,
    step_callback=step_callback
)

start_time = datetime.now()
try:
    logger.info("Starting bias detection process")
    results = bias_detection_crew.kickoff()

    # Generate metrics
    tableau_metrics = create_tableau_metrics(bias_detection_crew, start_time)

    # Save metrics to JSON
    metrics_file = log_dir / f'tableau_metrics_{start_time.strftime("%Y%m%d_%H%M%S")}.json'
    metrics_file.write_text(json.dumps(tableau_metrics, indent=2, cls=CrewMetricsEncoder))

    logger.info(f"Results: {results.raw}")
    logger.info(f"Metrics saved to: {metrics_file}")

except Exception as e:
    logger.error(f"Error during execution: {str(e)}")
